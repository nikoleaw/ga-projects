# %%
from __future__ import division
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import pylab as pl
import numpy as np
# Out:
# /anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
df_admin = pd.read_csv("admissions.csv")

# %%
df_admin.head()
# Out:
#    admit    gre   gpa  prestige
# 0      0  380.0  3.61       3.0
# 1      1  660.0  3.67       3.0
# 2      1  800.0  4.00       1.0
# 3      1  640.0  3.19       4.0
# 4      0  520.0  2.93       4.0

# %% [markdown]
# ## Questions:

# %%
#Number of observations
df_admin.count()
# Out:
# admit       400
# gre         398
# gpa         398
# prestige    399
# dtype: int64

# %%
df_admin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 4 columns):
# admit       400 non-null int64
# gre         398 non-null float64
# gpa         398 non-null float64
# prestige    399 non-null float64
# dtypes: float64(3), int64(1)
# memory usage: 12.6 KB

# %%
#Question 2. Create a summary table
df_admin.describe()
# Out:
#             admit         gre        gpa    prestige
# count  400.000000  398.000000  398.00000  399.000000
# mean     0.317500  588.040201    3.39093    2.486216
# std      0.466087  115.628513    0.38063    0.945333
# min      0.000000  220.000000    2.26000    1.000000
# 25%      0.000000  520.000000    3.13000    2.000000
# 50%      0.000000  580.000000    3.39500    2.000000
# 75%      1.000000  660.000000    3.67000    3.000000
# max      1.000000  800.000000    4.00000    4.000000

# %% [markdown]
# #####  #Question 3. Why would GRE have a larger STD than GPA?
#
# The GRE range is significantly wider, therefore leaving room for much larger deviation from the mean.

# %%
#Question 4. Drop data points with missing data
df_admin = df_admin.dropna()

# %%
#Question 5. Confirm that you dropped the correct data. How can you tell?
df_admin.isnull().sum()
# Out:
# admit       0
# gre         0
# gpa         0
# prestige    0
# dtype: int64

# %%
#Question 6. Create box plots for GRE and GPA
df_admin.gre.plot(kind = 'box')

# %%
df_admin.gpa.plot(kind = 'box')

# %% [markdown]
# #### #Question 7. What do this plots show?
# GRE has more outliers. GRE appears to have a tighter distribution sans the outliers.

# %%
#Question 8. Describe each distribution
df_admin.gre.plot(kind = 'hist', bins= 10)

# %%
df_admin.gpa.plot(kind = 'hist', bins= 10)

# %% [markdown]
# #Q 9 - 10
# Both distributions scew left. If we were looking for our model to have a normal distribution we would not meet that standard with the current. We can try taking the LOG to correct the distribution.

# %%
#Question 11. Which of our variables are potentially colinear?
corr = df_admin.corr()

# %%
#Collinearity in color?
plt.figure(figsize=(10, 10))
plt.imshow(corr, cmap='RdYlGn', interpolation='none', aspect='auto')
plt.colorbar()
plt.xticks(range(len(corr)), corr.columns, rotation='vertical')
plt.yticks(range(len(corr)), corr.columns);
plt.suptitle('Admission_Factors', fontsize=15, fontweight='bold')
plt.show()

# %%
import seaborn as sns

# %%
sns.pairplot(df_admin)

# %% [markdown]
# #### #Question 12. What did you find?
#
# GRE and GPA appear to have some collinearity happening

# %% [markdown]
# #### #Question 13. Write an analysis plan for exploring the association between grad school admissions rates and prestige of undergraduate schools. Question 14. What is your hypothesis?
#
# Since there currently doesnt appear to be any correlation between prestige and admission, maybe normalizing the data will paint a different picture. I think that prestige might not strongly correlate directly with with admission though. It could be a secondary factor after GRE and GPA.
